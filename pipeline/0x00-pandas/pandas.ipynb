# %% [markdown]
# # 0x00. Pandas
# <hr>

# %% [markdown]
# ## Tasks

# %% [markdown]
# Import libraries first

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 👉 0. From Numpy

# %%
def from_numpy(array):
    """
    ****************************************
    creates a pd.DataFrame from a np.ndarray
    ****************************************
    @array: np.ndarray for creation of the pd.DataFrame
    *** The columns of the pd.DataFrame should be labeled
        in alphabetical order and capitalized. There will
        not be more than 26 columns.
    Returns:
            the newly created pd.DataFrame
    """
    a=65
    alphab = np.array(list(map(chr, range(a, a+array.shape[1]))))
    df = pd.DataFrame(array)
    df.columns=alphab
    return df

# %%
# test
np.random.seed(0)
A = np.random.randn(5, 8)
print(from_numpy(A))
B = np.random.randn(9, 3)
print(from_numpy(B))
# Out:
#           A         B         C         D         E         F         G  \
# 0  1.764052  0.400157  0.978738  2.240893  1.867558 -0.977278  0.950088
# 1 -0.103219  0.410599  0.144044  1.454274  0.761038  0.121675  0.443863
# 2  1.494079 -0.205158  0.313068 -0.854096 -2.552990  0.653619  0.864436
# 3  2.269755 -1.454366  0.045759 -0.187184  1.532779  1.469359  0.154947
# 4 -0.887786 -1.980796 -0.347912  0.156349  1.230291  1.202380 -0.387327
#
#           H
# 0 -0.151357
# 1  0.333674
# 2 -0.742165
# 3  0.378163
# 4 -0.302303
#           A         B         C
# 0 -1.048553 -1.420018 -1.706270
# 1  1.950775 -0.509652 -0.438074
# 2 -1.252795  0.777490 -1.613898
# 3 -0.212740 -0.895467  0.386902
# 4 -0.510805 -1.180632 -0.028182
# 5  0.428332  0.066517  0.302472
# 6 -0.634322 -0.362741 -0.672460
# 7 -0.359553 -0.813146 -1.726283
# 8  0.177426 -0.401781 -1.630198

# %% [markdown]
# ### 👉 1. From Dictionary

# %%
"""
DataFrame From dict

The first column should be labeled First and have
the values 0.0, 0.5, 1.0, and 1.5
The second column should be labeled Second and have
the values one, two, three, four
The rows should be labeled A, B, C, and D, respectively
The pd.DataFrame should be saved into the variable df
"""
col = {
    "First" : [0.0, 0.5, 1.0, 1.5],
    "Second" : ['one' ,'two' ,'three' ,'four']
}
rows = ['A', 'B', 'C', 'D']

df = pd.DataFrame(col, index=rows)

print(df)
# Out:
#    First Second
# A    0.0    one
# B    0.5    two
# C    1.0  three
# D    1.5   four

# %% [markdown]
# ### 👉 2. From File

# %%
def from_file(filename, delimiter):
    """
    ****************************************
    loads data from a file as a pd.DataFrame
    ****************************************
    @filename: is the file to load from
    @delimiter: is the column separator
    Returns:
            the loaded pd.DataFrame
    """
    with open(filename, 'r') as f:
        headers = list(f.readline().strip().split(delimiter))
        body = []
        for line in f.readlines():
            body.append(np.array(line.strip().split(delimiter)))
    df = pd.DataFrame(np.array(body))
    df.columns = headers
    return df

# %%
df1 = from_file('../data/coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv', ',')
df1.head()
# Out:
#     Timestamp Open High  Low Close Volume_(BTC) Volume_(Currency)  \
# 0  1417411980  300  300  300   300         0.01                 3
# 1  1417412040  NaN  NaN  NaN   NaN          NaN               NaN
# 2  1417412100  NaN  NaN  NaN   NaN          NaN               NaN
# 3  1417412160  NaN  NaN  NaN   NaN          NaN               NaN
# 4  1417412220  NaN  NaN  NaN   NaN          NaN               NaN
#
#   Weighted_Price
# 0            300
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
df2 = from_file('../data/bitstampUSD_1-min_data_2012-01-01_to_2020-04-22.csv', ',')
df2.tail()
# Out:
#           Timestamp     Open     High      Low    Close Volume_(BTC)  \
# 4363452  1587513360  6847.97  6856.35  6847.97  6856.35   0.12517378
# 4363453  1587513420  6850.23  6856.13  6850.23  6850.89   1.22477701
# 4363454  1587513480   6846.5  6857.45  6846.02  6857.45   7.08916801
# 4363455  1587513540  6854.18  6854.98  6854.18  6854.98    0.0122307
# 4363456  1587513600   6850.6   6850.6   6850.6   6850.6   0.01443624
#
#         Volume_(Currency) Weighted_Price
# 4363452      858.12869735   6855.4987902
# 4363453      8396.7814587   6855.7634493
# 4363454      48533.089069   6846.0909659
# 4363455      83.831603886   6854.1950899
# 4363456      98.896905744         6850.6

# %% [markdown]
# ### 👉 3. Rename

# %%
"""
Rename the column Timestamp to Datetime
Convert the timestamp values to datatime values
Display only the Datetime and Close columns
"""

from_file = __import__('2-from_file').from_file

df = from_file('../data/coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv', ',')

# %%
df.head()
# Out:
#     Timestamp Open High  Low Close Volume_(BTC) Volume_(Currency)  \
# 0  1417411980  300  300  300   300         0.01                 3
# 1  1417412040  NaN  NaN  NaN   NaN          NaN               NaN
# 2  1417412100  NaN  NaN  NaN   NaN          NaN               NaN
# 3  1417412160  NaN  NaN  NaN   NaN          NaN               NaN
# 4  1417412220  NaN  NaN  NaN   NaN          NaN               NaN
#
#   Weighted_Price
# 0            300
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# YOUR CODE HERE
df = df.rename(columns={"Timestamp" : "Datetime"})

df.head()
# Out:
#      Datetime Open High  Low Close Volume_(BTC) Volume_(Currency)  \
# 0  1417411980  300  300  300   300         0.01                 3
# 1  1417412040  NaN  NaN  NaN   NaN          NaN               NaN
# 2  1417412100  NaN  NaN  NaN   NaN          NaN               NaN
# 3  1417412160  NaN  NaN  NaN   NaN          NaN               NaN
# 4  1417412220  NaN  NaN  NaN   NaN          NaN               NaN
#
#   Weighted_Price
# 0            300
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
df['Datetime'] = pd.to_datetime(df['Datetime'], unit='s')

# %%
df = df[['Datetime', 'Close']]
df.tail()
# Out:
#                    Datetime    Close
# 2099755 2019-01-07 22:02:00  4006.01
# 2099756 2019-01-07 22:03:00  4006.01
# 2099757 2019-01-07 22:04:00  4006.01
# 2099758 2019-01-07 22:05:00   4005.5
# 2099759 2019-01-07 22:06:00  4005.99

# %% [markdown]
# ### 👉 4. To Numpy

# %%
"""
take the last 10 rows of the columns High and
Close and convert them into a numpy.ndarray
"""
from_file = __import__('2-from_file').from_file

df = from_file('../data/coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv', ',')

# %%
A = df[['High', 'Close']].tail(10).to_numpy(dtype='float32') # YOUR CODE HERE

print(A)
# Out:
# [[4009.54 4007.01]
#  [4007.01 4003.49]
#  [4007.29 4006.57]
#  [4006.57 4006.56]
#  [4006.57 4006.01]
#  [4006.57 4006.01]
#  [4006.57 4006.01]
#  [4006.01 4006.01]
#  [4006.01 4005.5 ]
#  [4006.01 4005.99]]

# %% [markdown]
# ### 👉 5. Slice

# %%
"""
slice the pd.DataFrame along the columns High,
Low, Close, and Volume_BTC, taking every 60th row
"""
from_file = __import__('2-from_file').from_file

df = from_file('../data/coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv', ',')

# %%
df = df[['High', 'Low', 'Close', 'Volume_(BTC)']].iloc[::60]

df.tail()
# Out:
#             High      Low    Close Volume_(BTC)
# 2099460  4020.08  4020.07  4020.08   4.70498889
# 2099520  4020.94  4020.93  4020.94   2.11141082
# 2099580     4020  4019.01     4020   4.63703547
# 2099640     4017  4016.99     4017    2.3623721
# 2099700  4014.78   4013.5  4014.72   1.29155727

# %% [markdown]
# ### 👉 6. Flip it and Switch it

# %%
#!/usr/bin/env python3
"""
alter the pd.DataFrame such that the rows
and columns are transposed and the data is
sorted in reverse chronological order
"""
import pandas as pd
from_file = __import__('2-from_file').from_file

df = from_file('../data/coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv', ',')

# %%
df1 = df[::-1].T

df1.tail(8)
# Out:
#                         2099759       2099758       2099757       2099756  \
# Timestamp            1546898760    1546898700    1546898640    1546898580
# Open                    4005.51       4006.01       4006.01       4006.01
# High                    4006.01       4006.01       4006.01       4006.57
# Low                     4005.51        4005.5          4006          4006
# Close                   4005.99        4005.5       4006.01       4006.01
# Volume_(BTC)         1.75277819    2.69969991    1.19212256    0.90216366
# Volume_(Currency)  7021.1835463  10814.241898  4775.6473083  3614.0831685
# Weighted_Price     4005.7456136  4005.7199905  4006.0036347  4006.0172325
#
#                         2099755       2099754       2099753       2099752  \
# Timestamp            1546898520    1546898460    1546898400    1546898340
# Open                    4006.01       4006.57       4006.56       4003.49
# High                    4006.57       4006.57       4006.57       4007.29
# ...

# %% [markdown]
# ### 👉 7. Sort

# %%
#!/usr/bin/env python3

import pandas as pd
from_file = __import__('2-from_file').from_file

df = from_file('../data/coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv', ',')

df1 = df.sort_values(by="High", ascending=False)

# %%
df1.head(109073)
# Out:
#           Timestamp     Open     High      Low    Close Volume_(BTC)  \
# 1197407  1492757640      NaN      NaN      NaN      NaN          NaN
# 549583   1453888200      NaN      NaN      NaN      NaN          NaN
# 549627   1453890840      NaN      NaN      NaN      NaN          NaN
# 549611   1453889880      NaN      NaN      NaN      NaN          NaN
# 94249    1426568160      NaN      NaN      NaN      NaN          NaN
# ...             ...      ...      ...      ...      ...          ...
# 981      1417470840      NaN      NaN      NaN      NaN          NaN
# 1519559  1512086760  9999.99  9999.99  9981.59  9982.71  11.78975436
# 1608740  1517437620  9966.02  9999.99  9966.02   9998.5  27.63677709
# 1608467  1517421240  9999.99  9999.99  9987.44  9989.73  16.59657248
# 1608744  1517437860  9991.01  9999.99  9991.01  9999.99  37.65477549
#
#         Volume_(Currency) Weighted_Price
# 1197407               NaN            NaN
# 549583                NaN            NaN
# ...

# %% [markdown]
# ### 👉 8. Prune

# %%
#!/usr/bin/env python3

import pandas as pd
from_file = __import__('2-from_file').from_file

df = from_file('../data/coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv', ',')

# %%
df.dtypes
# Out:
# Timestamp            object
# Open                 object
# High                 object
# Low                  object
# Close                object
# Volume_(BTC)         object
# Volume_(Currency)    object
# Weighted_Price       object
# dtype: object

# %%
df1 = df.replace('NaN',np.NaN)
df1 = df1.dropna(subset=["Close"]) 
#pd.to_numeric(df["Close"])

df1.head()
# Out:
#        Timestamp Open High  Low Close Volume_(BTC) Volume_(Currency)  \
# 0     1417411980  300  300  300   300         0.01                 3
# 7     1417412400  300  300  300   300         0.01                 3
# 51    1417415040  370  370  370   370         0.01               3.7
# 77    1417416600  370  370  370   370   0.02655554         9.8255498
# 1436  1417498140  377  377  377   377         0.01              3.77
#
#      Weighted_Price
# 0               300
# 7               300
# 51              370
# 77              370
# 1436            377

# %% [markdown]
# ### 👉 9. Fill

# %%
#!/usr/bin/env python3
"""
script to fill in the missing data points in the pd.DataFrame:

- The column Weighted_Price should be removed
- missing values in Close should be set to the previous
  row’s Close
- missing values in High, Low, Open should be set to the
  previous row’s Close value
- missing values in Volume_(BTC) and Volume_(Currency)
  should be set to 0
"""
import pandas as pd
from_file = __import__('2-from_file').from_file

df = from_file('coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv', ',')

# %%
df1 = df.drop(columns=["Weighted_Price"])

# %%
df1.head()
# Out:
#     Timestamp Open High  Low Close Volume_(BTC) Volume_(Currency)
# 0  1417411980  300  300  300   300         0.01                 3
# 1  1417412040  NaN  NaN  NaN   NaN          NaN               NaN
# 2  1417412100  NaN  NaN  NaN   NaN          NaN               NaN
# 3  1417412160  NaN  NaN  NaN   NaN          NaN               NaN
# 4  1417412220  NaN  NaN  NaN   NaN          NaN               NaN

# %%
df1 = df1.replace('NaN',np.NaN)
df1["Close"] = df1["Close"].fillna(method='backfill')
v = df1["Close"]
df.fillna(value={"High": v, "Low" :v, "Open": v}, inplace=True)

# %%
df1.head()
# Out:
#     Timestamp Open High  Low Close Volume_(BTC) Volume_(Currency)
# 0  1417411980  300  300  300   300         0.01                 3
# 1  1417412040  NaN  NaN  NaN   300          NaN               NaN
# 2  1417412100  NaN  NaN  NaN   300          NaN               NaN
# 3  1417412160  NaN  NaN  NaN   300          NaN               NaN
# 4  1417412220  NaN  NaN  NaN   300          NaN               NaN

# %%
df1.tail()
# Out:
#           Timestamp     Open     High      Low    Close Volume_(BTC)  \
# 2099755  1546898520  4006.01  4006.57     4006  4006.01   3.38295374
# 2099756  1546898580  4006.01  4006.57     4006  4006.01   0.90216366
# 2099757  1546898640  4006.01  4006.01     4006  4006.01   1.19212256
# 2099758  1546898700  4006.01  4006.01   4005.5   4005.5   2.69969991
# 2099759  1546898760  4005.51  4006.01  4005.51  4005.99   1.75277819
#
#         Volume_(Currency)
# 2099755      13553.433078
# 2099756      3614.0831685
# 2099757      4775.6473083
# 2099758      10814.241898
# 2099759      7021.1835463

# %% [markdown]
# ### 👉 10. Indexing

# %%
#!/usr/bin/env python3
"""
index the pd.DataFrame on the Timestamp column
"""
import pandas as pd
from_file = __import__('2-from_file').from_file

df = from_file('coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv', ',')

# %%
df1 = df.set_index("Timestamp")

df1.tail()
# Out:
#                Open     High      Low    Close Volume_(BTC) Volume_(Currency)  \
# Timestamp
# 1546898520  4006.01  4006.57     4006  4006.01   3.38295374      13553.433078
# 1546898580  4006.01  4006.57     4006  4006.01   0.90216366      3614.0831685
# 1546898640  4006.01  4006.01     4006  4006.01   1.19212256      4775.6473083
# 1546898700  4006.01  4006.01   4005.5   4005.5   2.69969991      10814.241898
# 1546898760  4005.51  4006.01  4005.51  4005.99   1.75277819      7021.1835463
#
#            Weighted_Price
# Timestamp
# 1546898520   4006.3903085
# 1546898580   4006.0172325
# 1546898640   4006.0036347
# 1546898700   4005.7199905
# 1546898760   4005.7456136

# %% [markdown]
# ### 👉 11. Concat

# %%
#!/usr/bin/env python3
"""
index the pd.DataFrames on the
Timestamp columns and concatenate them:

- Concatenate the start of the bitstamp table onto
  the top of the coinbase table
- Include all timestamps from bitstamp up to
  and including timestamp 1417411920
- Add keys to the data labeled bitstamp and coinbase
  respectively
"""
import pandas as pd
from_file = __import__('2-from_file').from_file

df1 = from_file('../data/coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv', ',')
df2 = from_file('../data/bitstampUSD_1-min_data_2012-01-01_to_2020-04-22.csv', ',')

# %%
df1417411920 = df2.iloc[:1417411920]
df1417411920
# Out:
#           Timestamp     Open     High      Low    Close Volume_(BTC)  \
# 0        1325317920     4.39     4.39     4.39     4.39   0.45558087
# 1        1325317980      NaN      NaN      NaN      NaN          NaN
# 2        1325318040      NaN      NaN      NaN      NaN          NaN
# 3        1325318100      NaN      NaN      NaN      NaN          NaN
# 4        1325318160      NaN      NaN      NaN      NaN          NaN
# ...             ...      ...      ...      ...      ...          ...
# 4363452  1587513360  6847.97  6856.35  6847.97  6856.35   0.12517378
# 4363453  1587513420  6850.23  6856.13  6850.23  6850.89   1.22477701
# 4363454  1587513480   6846.5  6857.45  6846.02  6857.45   7.08916801
# 4363455  1587513540  6854.18  6854.98  6854.18  6854.98    0.0122307
# 4363456  1587513600   6850.6   6850.6   6850.6   6850.6   0.01443624
#
#         Volume_(Currency) Weighted_Price
# 0            2.0000000193           4.39
# 1                     NaN            NaN
# ...

# %%
df11 = pd.concat([df2.iloc[:1417411920].set_index(["Timestamp"]),
                df1.set_index(["Timestamp"])],
               keys=['bitstamp', 'coinbase'])

df11
# Out:
#                         Open     High      Low    Close Volume_(BTC)  \
#          Timestamp
# bitstamp 1325317920     4.39     4.39     4.39     4.39   0.45558087
#          1325317980      NaN      NaN      NaN      NaN          NaN
#          1325318040      NaN      NaN      NaN      NaN          NaN
#          1325318100      NaN      NaN      NaN      NaN          NaN
#          1325318160      NaN      NaN      NaN      NaN          NaN
# ...                      ...      ...      ...      ...          ...
# coinbase 1546898520  4006.01  4006.57     4006  4006.01   3.38295374
#          1546898580  4006.01  4006.57     4006  4006.01   0.90216366
#          1546898640  4006.01  4006.01     4006  4006.01   1.19212256
#          1546898700  4006.01  4006.01   4005.5   4005.5   2.69969991
#          1546898760  4005.51  4006.01  4005.51  4005.99   1.75277819
#
#                     Volume_(Currency) Weighted_Price
#          Timestamp
# ...

# %%
df
# Out:
#                         Open     High      Low    Close Volume_(BTC)  \
#          Timestamp
# bitstamp 1587513480   6846.5  6857.45  6846.02  6857.45   7.08916801
#          1587513540  6854.18  6854.98  6854.18  6854.98    0.0122307
#          1587513600   6850.6   6850.6   6850.6   6850.6   0.01443624
# coinbase 1417411980      300      300      300      300         0.01
#          1417412040      NaN      NaN      NaN      NaN          NaN
# ...                      ...      ...      ...      ...          ...
#          1546898520  4006.01  4006.57     4006  4006.01   3.38295374
#          1546898580  4006.01  4006.57     4006  4006.01   0.90216366
#          1546898640  4006.01  4006.01     4006  4006.01   1.19212256
#          1546898700  4006.01  4006.01   4005.5   4005.5   2.69969991
#          1546898760  4005.51  4006.01  4005.51  4005.99   1.75277819
#
#                     Volume_(Currency) Weighted_Price
#          Timestamp
# ...

# %% [markdown]
# ### 👉 12. Hierarchy

# %%
import pandas as pd
from_file = __import__('2-from_file').from_file

df1 = from_file('../data/coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv', ',')
df2 = from_file('../data/bitstampUSD_1-min_data_2012-01-01_to_2020-04-22.csv', ',')

# %%
df1.iloc[1417411980:1417417980]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Open, High, Low, Close, Volume_(BTC), Volume_(Currency), Weighted_Price]
# Index: []

# %%
# YOUR CODE HERE

#df = pd.concat([df2.iloc[1417411980:1417417980].set_index(["Timestamp"]),
#                df1.iloc[1417411980:1417417980].set_index(["Timestamp"])],
#               keys=['bitstamp', 'coinbase'])

df11 = df1.sort_values("Timestamp")
df = pd.concat([df2.set_index(["Timestamp"]),
                df1.set_index(["Timestamp"])],
               keys=['bitstamp', 'coinbase'])

# %%
df.swaplevel().sort_values()
# Out:
#                         Open     High      Low    Close Volume_(BTC)  \
# Timestamp
# 1325317920 bitstamp     4.39     4.39     4.39     4.39   0.45558087
# 1325317980 bitstamp      NaN      NaN      NaN      NaN          NaN
# 1325318040 bitstamp      NaN      NaN      NaN      NaN          NaN
# 1325318100 bitstamp      NaN      NaN      NaN      NaN          NaN
# 1325318160 bitstamp      NaN      NaN      NaN      NaN          NaN
# ...                      ...      ...      ...      ...          ...
# 1587513360 bitstamp  6847.97  6856.35  6847.97  6856.35   0.12517378
# 1587513420 bitstamp  6850.23  6856.13  6850.23  6850.89   1.22477701
# 1587513480 bitstamp   6846.5  6857.45  6846.02  6857.45   7.08916801
# 1587513540 bitstamp  6854.18  6854.98  6854.18  6854.98    0.0122307
# 1587513600 bitstamp   6850.6   6850.6   6850.6   6850.6   0.01443624
#
#                     Volume_(Currency) Weighted_Price
# Timestamp
# 1325317920 bitstamp      2.0000000193           4.39
# ...

# %% [markdown]
# ### 👉 13. Analyze

# %%
#!/usr/bin/env python3

import pandas as pd
from_file = __import__('2-from_file').from_file

df = from_file('../data/coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv', ',')

# %%
stats = df.set_index(["Timestamp"]).describe()

stats
# Out:
#            Open     High      Low    Close Volume_(BTC) Volume_(Currency)  \
# count   2099760  2099760  2099760  2099760      2099760           2099760
# unique   444694   411182   432870   445378      1469259           1988071
# top         NaN      NaN      NaN      NaN          NaN               NaN
# freq     109069   109069   109069   109069       109069            109069
#
#        Weighted_Price
# count         2099760
# unique        1786141
# top               NaN
# freq           109069

# %% [markdown]
# ### 👉 14. Visualize

# %%
dfpn = dfpn.astype('float')
"""
High: max

Low: min

Open: mean

Close: mean

Volume_(BTC): sum

Volume_(Currency): sum 
"""
dfm = dfpn['2017-01-01 00:00:00'::]

dfm.groupby(["Datetime"]).max()["High"]
dfm.groupby(["Datetime"]).min()['Low']
dfm.groupby(["Datetime"]).mean()[['Open', 'Close']]
dfm.groupby(["Datetime"]).cumsum()[['Volume_(BTC)', 'Volume_(Currency)']]

dfm.plot(kind='line', figsize=(10, 6))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-047f13f01571> in <module>
#      20 dfm.groupby(["Datetime"]).cumsum()[['Volume_(BTC)', 'Volume_(Currency)']]
#      21
# ---> 22 dfm.plot(kind='line', figsize=(10, 6))
#      23
#      24 plt.show()
#
# ~/.local/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
# ...

# %%
#!/usr/bin/env python3

from datetime import date
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from_file = __import__('2-from_file').from_file

df = from_file('../data/coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv', ',')

# YOUR CODE HERE

# %%
df.dtypes
# Out:
# Timestamp              int64
# Open                 float64
# High                 float64
# Low                  float64
# Close                float64
# Volume_(BTC)         float64
# Volume_(Currency)    float64
# Weighted_Price       float64
# dtype: object

# %%
dfp = df.drop("Weighted_Price", axis=1)
dfp
# Out:
#           Timestamp     Open     High      Low    Close  Volume_(BTC)  \
# 0        1417411980   300.00   300.00   300.00   300.00      0.010000
# 1        1417412040      NaN      NaN      NaN      NaN           NaN
# 2        1417412100      NaN      NaN      NaN      NaN           NaN
# 3        1417412160      NaN      NaN      NaN      NaN           NaN
# 4        1417412220      NaN      NaN      NaN      NaN           NaN
# ...             ...      ...      ...      ...      ...           ...
# 2099755  1546898520  4006.01  4006.57  4006.00  4006.01      3.382954
# 2099756  1546898580  4006.01  4006.57  4006.00  4006.01      0.902164
# 2099757  1546898640  4006.01  4006.01  4006.00  4006.01      1.192123
# 2099758  1546898700  4006.01  4006.01  4005.50  4005.50      2.699700
# 2099759  1546898760  4005.51  4006.01  4005.51  4005.99      1.752778
#
#          Volume_(Currency)
# 0                 3.000000
# 1                      NaN
# 2                      NaN
# ...

# %%
dfp = dfp.rename(columns={"Timestamp": "Datetime"})
dfp['Datetime'] = pd.to_datetime(dfp['Datetime'], unit='s')
dfp
# Out:
#                    Datetime     Open     High      Low    Close  Volume_(BTC)  \
# 0       2014-12-01 05:33:00   300.00   300.00   300.00   300.00      0.010000
# 1       2014-12-01 05:34:00      NaN      NaN      NaN      NaN           NaN
# 2       2014-12-01 05:35:00      NaN      NaN      NaN      NaN           NaN
# 3       2014-12-01 05:36:00      NaN      NaN      NaN      NaN           NaN
# 4       2014-12-01 05:37:00      NaN      NaN      NaN      NaN           NaN
# ...                     ...      ...      ...      ...      ...           ...
# 2099755 2019-01-07 22:02:00  4006.01  4006.57  4006.00  4006.01      3.382954
# 2099756 2019-01-07 22:03:00  4006.01  4006.57  4006.00  4006.01      0.902164
# 2099757 2019-01-07 22:04:00  4006.01  4006.01  4006.00  4006.01      1.192123
# 2099758 2019-01-07 22:05:00  4006.01  4006.01  4005.50  4005.50      2.699700
# 2099759 2019-01-07 22:06:00  4005.51  4006.01  4005.51  4005.99      1.752778
#
#          Volume_(Currency)
# ...

# %%
dfp.set_index("Datetime", inplace=True)
dfp
# Out:
#                         Open     High      Low    Close  Volume_(BTC)  \
# Datetime
# 2014-12-01 05:33:00   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01 05:34:00      NaN      NaN      NaN      NaN           NaN
# 2014-12-01 05:35:00      NaN      NaN      NaN      NaN           NaN
# 2014-12-01 05:36:00      NaN      NaN      NaN      NaN           NaN
# 2014-12-01 05:37:00      NaN      NaN      NaN      NaN           NaN
# ...                      ...      ...      ...      ...           ...
# 2019-01-07 22:02:00  4006.01  4006.57  4006.00  4006.01      3.382954
# 2019-01-07 22:03:00  4006.01  4006.57  4006.00  4006.01      0.902164
# 2019-01-07 22:04:00  4006.01  4006.01  4006.00  4006.01      1.192123
# 2019-01-07 22:05:00  4006.01  4006.01  4005.50  4005.50      2.699700
# 2019-01-07 22:06:00  4005.51  4006.01  4005.51  4005.99      1.752778
#
#                      Volume_(Currency)
# Datetime
# 2014-12-01 05:33:00           3.000000
# ...

# %%
dfp = dfp.replace('NaN',np.NaN)
dfp["Close"] = dfp["Close"].fillna(method='ffill')
dfp
# Out:
#                         Open     High      Low    Close  Volume_(BTC)  \
# Datetime
# 2014-12-01 05:33:00   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01 05:34:00      NaN      NaN      NaN   300.00           NaN
# 2014-12-01 05:35:00      NaN      NaN      NaN   300.00           NaN
# 2014-12-01 05:36:00      NaN      NaN      NaN   300.00           NaN
# 2014-12-01 05:37:00      NaN      NaN      NaN   300.00           NaN
# ...                      ...      ...      ...      ...           ...
# 2019-01-07 22:02:00  4006.01  4006.57  4006.00  4006.01      3.382954
# 2019-01-07 22:03:00  4006.01  4006.57  4006.00  4006.01      0.902164
# 2019-01-07 22:04:00  4006.01  4006.01  4006.00  4006.01      1.192123
# 2019-01-07 22:05:00  4006.01  4006.01  4005.50  4005.50      2.699700
# 2019-01-07 22:06:00  4005.51  4006.01  4005.51  4005.99      1.752778
#
#                      Volume_(Currency)
# Datetime
# 2014-12-01 05:33:00           3.000000
# ...

# %%
v = dfp["Close"]
dfpn = dfp.fillna(value={"High": v, "Low" :v, "Open": v, "Volume_(BTC)": 0, "Volume_(Currency)" :0})
dfpn
# Out:
#                         Open     High      Low    Close  Volume_(BTC)  \
# Datetime
# 2014-12-01 05:33:00   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01 05:34:00   300.00   300.00   300.00   300.00      0.000000
# 2014-12-01 05:35:00   300.00   300.00   300.00   300.00      0.000000
# 2014-12-01 05:36:00   300.00   300.00   300.00   300.00      0.000000
# 2014-12-01 05:37:00   300.00   300.00   300.00   300.00      0.000000
# ...                      ...      ...      ...      ...           ...
# 2019-01-07 22:02:00  4006.01  4006.57  4006.00  4006.01      3.382954
# 2019-01-07 22:03:00  4006.01  4006.57  4006.00  4006.01      0.902164
# 2019-01-07 22:04:00  4006.01  4006.01  4006.00  4006.01      1.192123
# 2019-01-07 22:05:00  4006.01  4006.01  4005.50  4005.50      2.699700
# 2019-01-07 22:06:00  4005.51  4006.01  4005.51  4005.99      1.752778
#
#                      Volume_(Currency)
# Datetime
# 2014-12-01 05:33:00           3.000000
# ...

# %%
dfm['Volume_(Currency)']
# Out:
# Datetime
# 2017-01-01 00:00:00     2065.524303
# 2017-01-01 00:01:00        0.000000
# 2017-01-01 00:02:00        0.000000
# 2017-01-01 00:03:00       38.934400
# 2017-01-01 00:04:00     5313.529708
#                            ...
# 2019-01-07 22:02:00    13553.433078
# 2019-01-07 22:03:00     3614.083169
# 2019-01-07 22:04:00     4775.647308
# 2019-01-07 22:05:00    10814.241898
# 2019-01-07 22:06:00     7021.183546
# Name: Volume_(Currency), Length: 1061167, dtype: float64

# %%
dfm = dfpn["2017-01-01"::]
cur = dfm.groupby(dfm.index.to_period("D"))['Volume_(Currency)'].sum()
High = dfm.groupby(dfm.index.to_period("D"))['High'].max()
Low = dfm.groupby(dfm.index.to_period("D"))['Low'].min()
Open = dfm.groupby(dfm.index.to_period("D"))['Open'].mean()
Close = dfm.groupby(dfm.index.to_period("D"))['Close'].mean()
#dfg = dfm.groupby(dfm.index.to_period("D"))['Volume_(BTC)', 'Volume_(Currency)'].sum()
btc = dfm.groupby(dfm.index.to_period("D"))['Volume_(BTC)'].sum()

pd.concat([High, Low, Open, Close, btc, cur], axis=1).plot(kind='line', figsize=(10, 8))

plt.show()
