# %%
#!touch 5-transformer.py 5-train.py
# !chmod +x *.py

# %%
#!/usr/bin/env python3
""" Dataset """
import tensorflow.compat.v2 as tf
import tensorflow_datasets as tfds


class Dataset():
    """ loads and preps a dataset for machine translation """

    def __init__(self):
        """
        *********************************************
        *****************Constructor*****************
        *********************************************
        """
        # 👇 contains the ted_hrlr_translate/pt_to_en tf.data.Dataset
        # train split, loaded as_supervided
        self.data_train = tfds.load('ted_hrlr_translate/pt_to_en',
                                    split='train', as_supervised=True)
        # 👇 contains the ted_hrlr_translate/pt_to_en tf.data.Dataset
        # validate split, loaded as_supervided
        self.data_valid = tfds.load('ted_hrlr_translate/pt_to_en',
                                    split='validation', as_supervised=True)
        # the Portuguese tokenizer created from the training set
        self.tokenizer_pt = self.tokenize_dataset(self.data_train)[0]
        # the English tokenizer created from the training set
        self.tokenizer_en = self.tokenize_dataset(self.data_train)[1]

    def tokenize_dataset(self, data):
        """
        ***************************************************
        ****Creates sub-word tokenizers for our dataset****
        ***************************************************
        @data: is a tf.data.Dataset whose examples are formatted as a tuple (pt, en)
               *pt is the tf.Tensor containing the Portuguese sentence
               *en is the tf.Tensor containing the corresponding English sentence
        *** The maximum vocab size should be set to 2**15
        Returns:
                tokenizer_pt: is the Portuguese tokenizer
                tokenizer_en: is the English tokenizer
        """
        tf.compat.v1.enable_eager_execution()
        builder = tfds.features.text.SubwordTextEncoder.build_from_corpus
        pt = builder((pt.numpy() for pt, _ in data.repeat(1)), 2**15)
        en = builder((en.numpy() for _, en in data.repeat(1)), 2**15)
        return pt, en
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-45979cd0ed9e> in <module>
#       2 """ Dataset """
#       3 import tensorflow.compat.v2 as tf
# ----> 4 import tensorflow_datasets as tfds
#       5
#       6
#
# ~/.local/lib/python3.6/site-packages/tensorflow_datasets/__init__.py in <module>
#      51 from tensorflow_datasets import object_detection
#      52 from tensorflow_datasets import question_answering
# ---> 53 from tensorflow_datasets import d4rl
#      54 from tensorflow_datasets import structured
#      55 from tensorflow_datasets import summarization
#
# ~/.local/lib/python3.6/site-packages/tensorflow_datasets/d4rl/__init__.py in <module>
#      15
#      16 """D4RL datasets."""
# ---> 17 from tensorflow_datasets.d4rl.d4rl_mujoco_ant import D4rlMujocoAnt
#      18 from tensorflow_datasets.d4rl.d4rl_mujoco_halfcheetah import D4rlMujocoHalfcheetah
#
# ~/.local/lib/python3.6/site-packages/tensorflow_datasets/d4rl/d4rl_mujoco_ant/__init__.py in <module>
#      16 """d4rl_mujoco_ant dataset."""
#      17
# ---> 18 from tensorflow_datasets.d4rl.d4rl_mujoco_ant.d4rl_mujoco_ant import D4rlMujocoAnt
#
# ~/.local/lib/python3.6/site-packages/tensorflow_datasets/d4rl/d4rl_mujoco_ant/d4rl_mujoco_ant.py in <module>
#      18 from typing import Any
#      19
# ---> 20 from tensorflow_datasets.d4rl import mujoco_dataset
#      21 import tensorflow_datasets.public_api as tfds
#      22
#
# ~/.local/lib/python3.6/site-packages/tensorflow_datasets/d4rl/mujoco_dataset.py in <module>
#      20 import dataclasses
#      21 import tensorflow.compat.v2 as tf
# ---> 22 from tensorflow_datasets.d4rl import dataset_utils
#      23 import tensorflow_datasets.public_api as tfds
#      24
#
# ~/.local/lib/python3.6/site-packages/tensorflow_datasets/d4rl/dataset_utils.py in <module>
#      19 import h5py
#      20 import numpy as np
# ---> 21 from tensorflow.io import gfile
#      22
#      23 _DESCRIPTION = """
#
# ModuleNotFoundError: No module named 'tensorflow.io'

# %%
#!/usr/bin/env python3

Dataset = __import__('0-dataset').Dataset
import tensorflow as tf

data = Dataset()
for pt, en in data.data_train.take(1):
    print(pt.numpy().decode('utf-8'))
    print(en.numpy().decode('utf-8'))
for pt, en in data.data_valid.take(1):
    print(pt.numpy().decode('utf-8'))
    print(en.numpy().decode('utf-8'))
print(type(data.tokenizer_pt))
print(type(data.tokenizer_en))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-dd695e5a3f19> in <module>
#       4 import tensorflow as tf
#       5
# ----> 6 data = Dataset()
#       7 for pt, en in data.data_train.take(1):
#       8     print(pt.numpy().decode('utf-8'))
#
# ~/hb/holbertonschool-machine_learning/supervised_learning/0x12-transformer_apps/0-dataset.py in __init__(self)
#      24         self.data_valid = tfds.load('ted_hrlr_translate/pt_to_en',
#      25                                     split='validation', as_supervised=True)
# ---> 26         pt, en = self.tokenize_dataset(self.data_train)
#      27         # the Portuguese tokenizer created from the training set
#      28         self.tokenizer_pt = pt
#
# ~/hb/holbertonschool-machine_learning/supervised_learning/0x12-transformer_apps/0-dataset.py in tokenize_dataset(self, data)
#      48         # tf.compat.v1.enable_eager_execution()
#      49         builder = tfds.features.text.SubwordTextEncoder.build_from_corpus
# ---> 50         pt = builder((pt.numpy() for pt, _ in data.repeat(1)), 2**15)
#      51         en = builder((en.numpy() for _, en in data.repeat(1)), 2**15)
#      52         return pt, en
#
# ~/.local/lib/python3.6/site-packages/tensorflow_core/python/data/ops/dataset_ops.py in __iter__(self)
#     341       return iterator_ops.IteratorV2(self)
#     342     else:
# --> 343       raise RuntimeError("__iter__() is only supported inside of tf.function "
#     344                          "or when eager execution is enabled.")
#     345
#
# RuntimeError: __iter__() is only supported inside of tf.function or when eager execution is enabled.

# %%
# !python3.6 loaddataset.py
# Out:
# 2021-06-16 02:24:53.454044: W tensorflow/core/platform/cloud/google_auth_provider.cc:178] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "Not found: Could not locate the credentials file.". Retrieving token from GCE failed with "Aborted: All 10 retry attempts failed. The last failure: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'".
# Downloading and preparing dataset ted_hrlr_translate/pt_to_en/1.0.0 (download: 124.94 MiB, generated: Unknown size, total: 124.94 MiB) to /home/khouloud/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:00<?, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:00<?, ? url/s]
# Dl Size...:   0%|                                     | 0/124 [00:00<?, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:   1%|▏                            | 1/124 [00:02<04:16,  2.09s/ MiB]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:   2%|▍                            | 2/124 [00:02<02:45,  1.35s/ MiB]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:   2%|▋                            | 3/124 [00:03<02:12,  1.10s/ MiB]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:   3%|▉                            | 4/124 [00:04<01:53,  1.06 MiB/s]
#
# Extraction completed...: 0 file [00:04, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:   4%|█▏                           | 5/124 [00:05<02:07,  1.07s/ MiB]
#
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:   5%|█▍                           | 6/124 [00:05<02:06,  1.07s/ MiB]
#
# Extraction completed...: 0 file [00:05, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:10<?, ? url/s]
# Dl Size...:   6%|█▋                           | 7/124 [00:10<03:10,  1.62s/ MiB]
#
# Extraction completed...: 0 file [00:10, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:11<?, ? url/s]
# Dl Size...:   6%|█▊                           | 8/124 [00:11<03:03,  1.58s/ MiB]
#
# Extraction completed...: 0 file [00:11, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:13<?, ? url/s]
# Dl Size...:   7%|██                           | 9/124 [00:13<03:08,  1.64s/ MiB]
#
# Extraction completed...: 0 file [00:13, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:13<?, ? url/s]
# Dl Size...:   8%|██▎                         | 10/124 [00:13<02:28,  1.30s/ MiB]
#
# Extraction completed...: 0 file [00:13, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:14<?, ? url/s]
# Dl Size...:   9%|██▍                         | 11/124 [00:14<02:17,  1.21s/ MiB]
#
# Extraction completed...: 0 file [00:14, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:15<?, ? url/s]
# Dl Size...:  10%|██▋                         | 12/124 [00:15<01:55,  1.03s/ MiB]
#
# Extraction completed...: 0 file [00:15, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:16<?, ? url/s]
# Dl Size...:  10%|██▉                         | 13/124 [00:16<01:44,  1.06 MiB/s]
#
# Extraction completed...: 0 file [00:16, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:16<?, ? url/s]
# Dl Size...:  11%|███▏                        | 14/124 [00:16<01:34,  1.17 MiB/s]
#
# Extraction completed...: 0 file [00:16, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:17<?, ? url/s]
# Dl Size...:  12%|███▍                        | 15/124 [00:17<01:22,  1.32 MiB/s]
#
# Extraction completed...: 0 file [00:17, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:17<?, ? url/s]
# Dl Size...:  13%|███▌                        | 16/124 [00:17<01:22,  1.32 MiB/s]
#
# Extraction completed...: 0 file [00:17, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:19<?, ? url/s]
# Dl Size...:  14%|███▊                        | 17/124 [00:19<01:54,  1.07s/ MiB]
#
# Extraction completed...: 0 file [00:19, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:20<?, ? url/s]
# Dl Size...:  15%|████                        | 18/124 [00:20<01:46,  1.01s/ MiB]
#
# Extraction completed...: 0 file [00:20, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:21<?, ? url/s]
# Dl Size...:  15%|████▎                       | 19/124 [00:21<01:52,  1.07s/ MiB]
#
# Extraction completed...: 0 file [00:21, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:23<?, ? url/s]
# Dl Size...:  16%|████▌                       | 20/124 [00:23<02:07,  1.23s/ MiB]
#
# Extraction completed...: 0 file [00:23, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:23<?, ? url/s]
# Dl Size...:  17%|████▋                       | 21/124 [00:23<01:40,  1.02 MiB/s]
#
# Extraction completed...: 0 file [00:23, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:24<?, ? url/s]
# Dl Size...:  18%|████▉                       | 22/124 [00:24<01:33,  1.09 MiB/s]
#
# Extraction completed...: 0 file [00:24, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:25<?, ? url/s]
# Dl Size...:  19%|█████▏                      | 23/124 [00:25<01:27,  1.16 MiB/s]
#
# Extraction completed...: 0 file [00:25, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:26<?, ? url/s]
# Dl Size...:  19%|█████▍                      | 24/124 [00:26<01:31,  1.10 MiB/s]
#
# Extraction completed...: 0 file [00:26, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:27<?, ? url/s]
# Dl Size...:  20%|█████▋                      | 25/124 [00:27<01:24,  1.17 MiB/s]
#
# Extraction completed...: 0 file [00:27, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:27<?, ? url/s]
# Dl Size...:  21%|█████▊                      | 26/124 [00:27<01:15,  1.30 MiB/s]
#
# Extraction completed...: 0 file [00:27, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:28<?, ? url/s]
# Dl Size...:  22%|██████                      | 27/124 [00:28<01:14,  1.30 MiB/s]
#
# Extraction completed...: 0 file [00:28, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:29<?, ? url/s]
# Dl Size...:  23%|██████▎                     | 28/124 [00:29<01:17,  1.24 MiB/s]
#
# Extraction completed...: 0 file [00:29, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:29<?, ? url/s]
# Dl Size...:  23%|██████▌                     | 29/124 [00:29<01:04,  1.47 MiB/s]
#
# Extraction completed...: 0 file [00:29, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:30<?, ? url/s]
# Dl Size...:  24%|██████▊                     | 30/124 [00:30<01:06,  1.42 MiB/s]
#
# Extraction completed...: 0 file [00:30, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:31<?, ? url/s]
# Dl Size...:  25%|███████                     | 31/124 [00:31<01:06,  1.40 MiB/s]
#
# Extraction completed...: 0 file [00:31, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:31<?, ? url/s]
# Dl Size...:  26%|███████▏                    | 32/124 [00:31<01:00,  1.52 MiB/s]
#
# Extraction completed...: 0 file [00:31, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:32<?, ? url/s]
# Dl Size...:  27%|███████▍                    | 33/124 [00:32<00:59,  1.52 MiB/s]
#
# Extraction completed...: 0 file [00:32, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:32<?, ? url/s]
# Dl Size...:  27%|███████▋                    | 34/124 [00:32<00:56,  1.59 MiB/s]
#
# Extraction completed...: 0 file [00:32, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:33<?, ? url/s]
# Dl Size...:  28%|███████▉                    | 35/124 [00:33<01:05,  1.36 MiB/s]
#
# Extraction completed...: 0 file [00:33, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:34<?, ? url/s]
# Dl Size...:  29%|████████▏                   | 36/124 [00:34<00:59,  1.47 MiB/s]
#
# Extraction completed...: 0 file [00:34, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:35<?, ? url/s]
# Dl Size...:  30%|████████▎                   | 37/124 [00:35<01:05,  1.33 MiB/s]
#
# Extraction completed...: 0 file [00:35, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:35<?, ? url/s]
# Dl Size...:  31%|████████▌                   | 38/124 [00:35<00:59,  1.44 MiB/s]
#
# Extraction completed...: 0 file [00:35, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:36<?, ? url/s]
# Dl Size...:  31%|████████▊                   | 39/124 [00:36<01:01,  1.38 MiB/s]
#
# Extraction completed...: 0 file [00:36, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:37<?, ? url/s]
# Dl Size...:  32%|█████████                   | 40/124 [00:37<01:02,  1.35 MiB/s]
#
# Extraction completed...: 0 file [00:37, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:38<?, ? url/s]
# Dl Size...:  33%|█████████▎                  | 41/124 [00:38<01:01,  1.34 MiB/s]
#
# Extraction completed...: 0 file [00:38, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:38<?, ? url/s]
# Dl Size...:  34%|█████████▍                  | 42/124 [00:38<00:58,  1.40 MiB/s]
#
# Extraction completed...: 0 file [00:38, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:39<?, ? url/s]
# Dl Size...:  35%|█████████▋                  | 43/124 [00:39<01:00,  1.35 MiB/s]
#
# Extraction completed...: 0 file [00:39, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:40<?, ? url/s]
# Dl Size...:  35%|█████████▉                  | 44/124 [00:40<00:57,  1.40 MiB/s]
#
# Extraction completed...: 0 file [00:40, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:41<?, ? url/s]
# Dl Size...:  36%|██████████▏                 | 45/124 [00:41<01:13,  1.07 MiB/s]
#
# Extraction completed...: 0 file [00:41, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:42<?, ? url/s]
# Dl Size...:  37%|██████████▍                 | 46/124 [00:42<01:11,  1.09 MiB/s]
#
# Extraction completed...: 0 file [00:42, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:43<?, ? url/s]
# Dl Size...:  38%|██████████▌                 | 47/124 [00:43<00:57,  1.33 MiB/s]
#
# Extraction completed...: 0 file [00:43, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:44<?, ? url/s]
# Dl Size...:  39%|██████████▊                 | 48/124 [00:44<01:05,  1.17 MiB/s]
#
# Extraction completed...: 0 file [00:44, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:45<?, ? url/s]
# Dl Size...:  40%|███████████                 | 49/124 [00:45<01:06,  1.14 MiB/s]
#
# Extraction completed...: 0 file [00:45, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:46<?, ? url/s]
# Dl Size...:  40%|███████████▎                | 50/124 [00:46<01:12,  1.01 MiB/s]
#
# Extraction completed...: 0 file [00:46, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:49<?, ? url/s]
# Dl Size...:  41%|███████████▌                | 51/124 [00:49<02:01,  1.67s/ MiB]
#
# Dl Completed...:   0%|                                  | 0/1 [00:49<?, ? url/s]
# Dl Size...:  42%|███████████▋                | 52/124 [00:49<01:59,  1.67s/ MiB]
#
# Extraction completed...: 0 file [00:49, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:51<?, ? url/s]
# Dl Size...:  43%|███████████▉                | 53/124 [00:51<01:39,  1.40s/ MiB]
#
# Extraction completed...: 0 file [00:51, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:53<?, ? url/s]
# Dl Size...:  44%|████████████▏               | 54/124 [00:53<01:43,  1.48s/ MiB]
#
# Extraction completed...: 0 file [00:53, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:55<?, ? url/s]
# Dl Size...:  44%|████████████▍               | 55/124 [00:55<01:48,  1.58s/ MiB]
#
# Extraction completed...: 0 file [00:55, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:57<?, ? url/s]
# Dl Size...:  45%|████████████▋               | 56/124 [00:57<01:48,  1.60s/ MiB]
#
# Extraction completed...: 0 file [00:57, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:58<?, ? url/s]
# Dl Size...:  46%|████████████▊               | 57/124 [00:58<01:47,  1.61s/ MiB]
#
# Extraction completed...: 0 file [00:58, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:00<?, ? url/s]
# Dl Size...:  47%|█████████████               | 58/124 [01:00<01:47,  1.64s/ MiB]
#
# Extraction completed...: 0 file [01:00, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:01<?, ? url/s]
# Dl Size...:  48%|█████████████▎              | 59/124 [01:01<01:42,  1.57s/ MiB]
#
# Extraction completed...: 0 file [01:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:04<?, ? url/s]
# Dl Size...:  48%|█████████████▌              | 60/124 [01:04<01:59,  1.87s/ MiB]
#
# Extraction completed...: 0 file [01:04, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:05<?, ? url/s]
# Dl Size...:  49%|█████████████▊              | 61/124 [01:05<01:50,  1.75s/ MiB]
#
# Extraction completed...: 0 file [01:05, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:08<?, ? url/s]
# Dl Size...:  50%|██████████████              | 62/124 [01:08<02:01,  1.96s/ MiB]
#
# Extraction completed...: 0 file [01:08, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:10<?, ? url/s]
# Dl Size...:  51%|██████████████▏             | 63/124 [01:10<02:00,  1.98s/ MiB]
#
# Extraction completed...: 0 file [01:10, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:11<?, ? url/s]
# Dl Size...:  52%|██████████████▍             | 64/124 [01:11<01:47,  1.79s/ MiB]
#
# Extraction completed...: 0 file [01:11, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:13<?, ? url/s]
# Dl Size...:  52%|██████████████▋             | 65/124 [01:13<01:48,  1.85s/ MiB]
#
# Extraction completed...: 0 file [01:13, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:14<?, ? url/s]
# Dl Size...:  53%|██████████████▉             | 66/124 [01:14<01:35,  1.65s/ MiB]
#
# Extraction completed...: 0 file [01:14, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:16<?, ? url/s]
# Dl Size...:  54%|███████████████▏            | 67/124 [01:16<01:28,  1.55s/ MiB]
#
# Extraction completed...: 0 file [01:16, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:17<?, ? url/s]
# Dl Size...:  55%|███████████████▎            | 68/124 [01:17<01:20,  1.43s/ MiB]
#
# Extraction completed...: 0 file [01:17, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:19<?, ? url/s]
# Dl Size...:  56%|███████████████▌            | 69/124 [01:19<01:30,  1.64s/ MiB]
#
# Extraction completed...: 0 file [01:19, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:20<?, ? url/s]
# Dl Size...:  56%|███████████████▊            | 70/124 [01:20<01:23,  1.55s/ MiB]
#
# Extraction completed...: 0 file [01:20, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:21<?, ? url/s]
# Dl Size...:  57%|████████████████            | 71/124 [01:21<01:11,  1.35s/ MiB]
#
# Extraction completed...: 0 file [01:21, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:22<?, ? url/s]
# Dl Size...:  58%|████████████████▎           | 72/124 [01:22<01:05,  1.26s/ MiB]
#
# Extraction completed...: 0 file [01:22, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:24<?, ? url/s]
# Dl Size...:  59%|████████████████▍           | 73/124 [01:24<01:10,  1.38s/ MiB]
#
# Extraction completed...: 0 file [01:24, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:25<?, ? url/s]
# Dl Size...:  60%|████████████████▋           | 74/124 [01:25<01:10,  1.41s/ MiB]
#
# Extraction completed...: 0 file [01:25, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:26<?, ? url/s]
# Dl Size...:  60%|████████████████▉           | 75/124 [01:26<01:03,  1.29s/ MiB]
#
# Extraction completed...: 0 file [01:26, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:28<?, ? url/s]
# Dl Size...:  61%|█████████████████▏          | 76/124 [01:28<01:04,  1.33s/ MiB]
#
# Extraction completed...: 0 file [01:28, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:29<?, ? url/s]
# Dl Size...:  62%|█████████████████▍          | 77/124 [01:29<00:55,  1.17s/ MiB]
#
# Extraction completed...: 0 file [01:29, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:30<?, ? url/s]
# Dl Size...:  63%|█████████████████▌          | 78/124 [01:30<00:54,  1.18s/ MiB]
#
# Extraction completed...: 0 file [01:30, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:31<?, ? url/s]
# Dl Size...:  64%|█████████████████▊          | 79/124 [01:31<00:51,  1.14s/ MiB]
#
# Extraction completed...: 0 file [01:31, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:33<?, ? url/s]
# Dl Size...:  65%|██████████████████          | 80/124 [01:33<01:01,  1.39s/ MiB]
#
# Extraction completed...: 0 file [01:33, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:34<?, ? url/s]
# Dl Size...:  65%|██████████████████▎         | 81/124 [01:34<00:57,  1.33s/ MiB]
#
# Extraction completed...: 0 file [01:34, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:35<?, ? url/s]
# Dl Size...:  66%|██████████████████▌         | 82/124 [01:35<00:46,  1.12s/ MiB]
#
# Extraction completed...: 0 file [01:35, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:36<?, ? url/s]
# Dl Size...:  67%|██████████████████▋         | 83/124 [01:36<00:45,  1.12s/ MiB]
#
# Extraction completed...: 0 file [01:36, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:37<?, ? url/s]
# Dl Size...:  68%|██████████████████▉         | 84/124 [01:37<00:46,  1.15s/ MiB]
#
# Extraction completed...: 0 file [01:37, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:39<?, ? url/s]
# Dl Size...:  69%|███████████████████▏        | 85/124 [01:39<00:55,  1.42s/ MiB]
#
# Extraction completed...: 0 file [01:39, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:41<?, ? url/s]
# Dl Size...:  69%|███████████████████▍        | 86/124 [01:41<00:58,  1.53s/ MiB]
#
# Extraction completed...: 0 file [01:41, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:42<?, ? url/s]
# Dl Size...:  70%|███████████████████▋        | 87/124 [01:42<00:53,  1.44s/ MiB]
#
# Extraction completed...: 0 file [01:42, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:44<?, ? url/s]
# Dl Size...:  71%|███████████████████▊        | 88/124 [01:44<00:53,  1.47s/ MiB]
#
# Extraction completed...: 0 file [01:44, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:45<?, ? url/s]
# Dl Size...:  72%|████████████████████        | 89/124 [01:45<00:53,  1.52s/ MiB]
#
# Extraction completed...: 0 file [01:45, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:47<?, ? url/s]
# Dl Size...:  73%|████████████████████▎       | 90/124 [01:47<00:51,  1.52s/ MiB]
#
# Extraction completed...: 0 file [01:47, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:48<?, ? url/s]
# Dl Size...:  73%|████████████████████▌       | 91/124 [01:48<00:45,  1.37s/ MiB]
#
# Extraction completed...: 0 file [01:48, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:49<?, ? url/s]
# Dl Size...:  74%|████████████████████▊       | 92/124 [01:49<00:41,  1.28s/ MiB]
#
# Extraction completed...: 0 file [01:49, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:50<?, ? url/s]
# Dl Size...:  75%|█████████████████████       | 93/124 [01:50<00:38,  1.23s/ MiB]
#
# Extraction completed...: 0 file [01:50, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:51<?, ? url/s]
# Dl Size...:  76%|█████████████████████▏      | 94/124 [01:51<00:32,  1.10s/ MiB]
#
# Extraction completed...: 0 file [01:51, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:52<?, ? url/s]
# Dl Size...:  77%|█████████████████████▍      | 95/124 [01:52<00:32,  1.10s/ MiB]
#
# Extraction completed...: 0 file [01:52, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:53<?, ? url/s]
# Dl Size...:  77%|█████████████████████▋      | 96/124 [01:53<00:31,  1.12s/ MiB]
#
# Extraction completed...: 0 file [01:53, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:54<?, ? url/s]
# Dl Size...:  78%|█████████████████████▉      | 97/124 [01:54<00:27,  1.01s/ MiB]
#
# Extraction completed...: 0 file [01:54, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:55<?, ? url/s]
# Dl Size...:  79%|██████████████████████▏     | 98/124 [01:55<00:26,  1.04s/ MiB]
#
# Extraction completed...: 0 file [01:55, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:56<?, ? url/s]
# Dl Size...:  80%|██████████████████████▎     | 99/124 [01:56<00:25,  1.04s/ MiB]
#
# Extraction completed...: 0 file [01:56, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:57<?, ? url/s]
# Dl Size...:  81%|█████████████████████▊     | 100/124 [01:57<00:26,  1.09s/ MiB]
#
# Extraction completed...: 0 file [01:57, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:59<?, ? url/s]
# Dl Size...:  81%|█████████████████████▉     | 101/124 [01:59<00:30,  1.32s/ MiB]
#
# Extraction completed...: 0 file [01:59, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:00<?, ? url/s]
# Dl Size...:  82%|██████████████████████▏    | 102/124 [02:00<00:28,  1.31s/ MiB]
#
# Extraction completed...: 0 file [02:00, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:01<?, ? url/s]
# Dl Size...:  83%|██████████████████████▍    | 103/124 [02:01<00:26,  1.25s/ MiB]
#
# Extraction completed...: 0 file [02:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:03<?, ? url/s]
# Dl Size...:  84%|██████████████████████▋    | 104/124 [02:03<00:27,  1.38s/ MiB]
#
# Extraction completed...: 0 file [02:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:04<?, ? url/s]
# Dl Size...:  85%|██████████████████████▊    | 105/124 [02:04<00:25,  1.34s/ MiB]
#
# Extraction completed...: 0 file [02:04, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:06<?, ? url/s]
# Dl Size...:  85%|███████████████████████    | 106/124 [02:06<00:24,  1.38s/ MiB]
#
# Extraction completed...: 0 file [02:06, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:07<?, ? url/s]
# Dl Size...:  86%|███████████████████████▎   | 107/124 [02:07<00:20,  1.22s/ MiB]
#
# Extraction completed...: 0 file [02:07, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:08<?, ? url/s]
# Dl Size...:  87%|███████████████████████▌   | 108/124 [02:08<00:20,  1.27s/ MiB]
#
# Extraction completed...: 0 file [02:08, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:10<?, ? url/s]
# Dl Size...:  88%|███████████████████████▋   | 109/124 [02:10<00:21,  1.42s/ MiB]
#
# Extraction completed...: 0 file [02:10, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:12<?, ? url/s]
# Dl Size...:  89%|███████████████████████▉   | 110/124 [02:12<00:21,  1.51s/ MiB]
#
# Extraction completed...: 0 file [02:12, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:14<?, ? url/s]
# Dl Size...:  90%|████████████████████████▏  | 111/124 [02:14<00:24,  1.85s/ MiB]
#
# Extraction completed...: 0 file [02:14, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:16<?, ? url/s]
# Dl Size...:  90%|████████████████████████▍  | 112/124 [02:16<00:21,  1.82s/ MiB]
#
# Extraction completed...: 0 file [02:16, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:18<?, ? url/s]
# Dl Size...:  91%|████████████████████████▌  | 113/124 [02:18<00:20,  1.88s/ MiB]
#
# Extraction completed...: 0 file [02:18, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:20<?, ? url/s]
# Dl Size...:  92%|████████████████████████▊  | 114/124 [02:20<00:19,  1.99s/ MiB]
#
# Extraction completed...: 0 file [02:20, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:21<?, ? url/s]
# Dl Size...:  93%|█████████████████████████  | 115/124 [02:21<00:15,  1.75s/ MiB]
#
# Extraction completed...: 0 file [02:21, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:23<?, ? url/s]
# Dl Size...:  94%|█████████████████████████▎ | 116/124 [02:23<00:12,  1.59s/ MiB]
#
# Extraction completed...: 0 file [02:23, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:23<?, ? url/s]
# Dl Size...:  94%|█████████████████████████▍ | 117/124 [02:23<00:09,  1.33s/ MiB]
#
# Extraction completed...: 0 file [02:23, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:24<?, ? url/s]
# Dl Size...:  95%|█████████████████████████▋ | 118/124 [02:24<00:07,  1.21s/ MiB]
#
# Extraction completed...: 0 file [02:24, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:25<?, ? url/s]
# Dl Size...:  96%|█████████████████████████▉ | 119/124 [02:25<00:05,  1.16s/ MiB]
#
# Extraction completed...: 0 file [02:25, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:26<?, ? url/s]
# Dl Size...:  97%|██████████████████████████▏| 120/124 [02:26<00:04,  1.15s/ MiB]
#
# Extraction completed...: 0 file [02:26, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:28<?, ? url/s]
# Dl Size...:  98%|██████████████████████████▎| 121/124 [02:28<00:03,  1.30s/ MiB]
#
# Extraction completed...: 0 file [02:28, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:29<?, ? url/s]
# Dl Size...:  98%|██████████████████████████▌| 122/124 [02:29<00:02,  1.17s/ MiB]
#
# Extraction completed...: 0 file [02:29, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:30<?, ? url/s]
# Dl Size...:  99%|██████████████████████████▊| 123/124 [02:30<00:01,  1.13s/ MiB]
#
# Extraction completed...: 0 file [02:30, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:31<?, ? url/s]
# Dl Size...: 100%|███████████████████████████| 124/124 [02:31<00:00,  1.21s/ MiB]
#
# Dl Completed...: 100%|█████████████████████████| 1/1 [02:32<00:00, 152.80s/ url]
# Dl Size...: 100%|███████████████████████████| 124/124 [02:32<00:00,  1.21s/ MiB]
#
# Dl Completed...: 100%|█████████████████████████| 1/1 [02:32<00:00, 152.80s/ url]
# Dl Size...: 100%|███████████████████████████| 124/124 [02:32<00:00,  1.21s/ MiB]
#
# Extraction completed...:   0%|                         | 0/1 [02:32<?, ? file/s]
#
# Dl Completed...: 100%|█████████████████████████| 1/1 [02:39<00:00, 152.80s/ url]
# Dl Size...: 100%|███████████████████████████| 124/124 [02:39<00:00,  1.21s/ MiB]
#
# Extraction completed...: 100%|████████████████| 1/1 [02:39<00:00, 159.64s/ file]
# Extraction completed...: 100%|████████████████| 1/1 [02:39<00:00, 159.64s/ file]
#
# Dl Size...: 100%|███████████████████████████| 124/124 [02:39<00:00,  1.29s/ MiB]
#
# Dl Completed...: 100%|█████████████████████████| 1/1 [02:39<00:00, 159.65s/ url]
# Shuffling and writing examples to /home/khouloud/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0.incomplete1IIB18/ted_hrlr_translate-train.tfrecord
# Shuffling and writing examples to /home/khouloud/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0.incomplete1IIB18/ted_hrlr_translate-validation.tfrecord
# Shuffling and writing examples to /home/khouloud/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0.incomplete1IIB18/ted_hrlr_translate-test.tfrecord
# Dataset ted_hrlr_translate downloaded and prepared to /home/khouloud/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0. Subsequent calls will reuse this data.
# Traceback (most recent call last):
#   File "loaddataset.py", line 6, in <module>
#     for pt, en in pt2en_train.take(1):
#   File "/home/khouloud/.local/lib/python3.6/site-packages/tensorflow_core/python/data/ops/dataset_ops.py", line 343, in __iter__
#     raise RuntimeError("__iter__() is only supported inside of tf.function "
# RuntimeError: __iter__() is only supported inside of tf.function or when eager execution is enabled.

# %%
# !python3.6 m.py
# Out:
# 2021-06-16 03:00:59.694649: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-06-16 03:00:59.694699: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-06-16 03:00:59.694734: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ggirlk): /proc/driver/nvidia/version does not exist
# 2021-06-16 03:00:59.724186: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2195085000 Hz
# 2021-06-16 03:00:59.724853: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x41222c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-06-16 03:00:59.724929: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# got here
# tf.Tensor(
# [30138     6    36 17925    13     3  3037     1  4880     3   387  2832
#     18 18444     1     5     8     3 16679 19460   739     2 30139], shape=(23,), dtype=int64) tf.Tensor(
# [28543     4    56    15  1266 20397 10721     1    15   100   125   352
#      3    45  3066     6  8004     1    88    13 14859     2 28544], shape=(23,), dtype=int64)
# tf.Tensor([30138   289 15409  2591    19 20318 26024 29997    28 30139], shape=(10,), dtype=int64) tf.Tensor([28543    93    25   907  1366     4  5742    33 28544], shape=(9,), dtype=int64)
